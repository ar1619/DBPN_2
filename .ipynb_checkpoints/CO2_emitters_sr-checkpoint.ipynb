# %% [markdown]
# This notebook is based on TCCON_analysis in emissions_data folder

# %%
from netCDF4 import Dataset as NetCDFFile
import netCDF4 as ncd
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cftime as cft
import time
import json
import glob

import cartopy.crs as ccrs

# %%
from __future__ import print_function
import argparse

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from model import Net as DBPNLL
from data import get_eval_set
from functools import reduce
from skimage.transform import pyramid_reduce, pyramid_expand

import scipy.io as sio

# %%
def normalize_array(data):
    vmax = np.amax(data[np.nonzero(data)])
    vmin = np.amin(data[np.nonzero(data)])
    range_data = vmax - vmin
    
    normalized_data = (data - vmin)/range_data
    threshold = - 1./range_data
    data = np.maximum(normalized_data,threshold)
    data[data == threshold] = -1
    
    return data

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
# The boundary format is low_lat, left_lon, high_lat and right_lon
def arrays_centered_on_factory(coordinates, day, lat, lon, size, xco2_array):
    nb_polluters = len(coordinates)
    for indx in range(nb_polluters):
        boundaries = np.zeros(4)
        boundaries[0] = find_nearest(lat, float(coordinates[indx, 1]) - size)
        boundaries[1] = find_nearest(lon, float(coordinates[indx, 2]) - size)
        boundaries[2] = find_nearest(lat, float(coordinates[indx, 1]) + size)
        boundaries[3] = find_nearest(lon, float(coordinates[indx, 2]) + size)
        boundaries = boundaries.astype(int)
        np.save('/data/andria/Input/emitters/centered_{}_{}.npy'.format(day, indx), xco2_array[boundaries[0]:boundaries[2],
                                                                                           boundaries[1]:boundaries[3]])

# %%
def save_img(img, img_name):
    save_arr = img.numpy().squeeze(axis = 0).squeeze(axis = 0)
    # save img
    save_dir=os.path.join('/data/andria/Results/','emitters')
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        
    save_fn = save_dir +'/'+ img_name
    np.save(save_fn, save_arr)

# %%
coordinates = np.load('../../../emissions_data/coordinates_emitters.npy', allow_pickle = True)

# %%
#4 days per year to account for seasonality
list_of_days = ['20150120', '20150420', '20150720', '20151020',
               '20160120', '20160420', '20160720', '20161020',
               '20170120', '20170420', '20170720', '20171020',
               '20180120', '20180420', '20180720', '20181020',
               '20190120', '20190420', '20190720', '20191020',
               '20200120', '20200420', '20200720', '20201020',
               '20210120', '20210420', '20210720', '20211020']

# %%
model_w_16 = 'weights/MOD_tensorese-hivemindDBPNLL1channel_16_MSE.pth'

gpus_list=range(1)
cuda = True
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

torch.manual_seed(123)
if cuda:
    torch.cuda.manual_seed(123)
    
print('===> Building models')
model_16 = DBPNLL(num_channels=1, base_filter=64,  feat = 256, num_stages=10, scale_factor=16)

if cuda:
    model_16 = torch.nn.DataParallel(model_16, device_ids=gpus_list)

model_16.load_state_dict(torch.load(model_w_16, map_location=lambda storage, loc: storage))
print('Pre-trained SR model is loaded.')

if cuda:
    model_16 = model_16.cuda(gpus_list[0])
# Out:
# ===> Building models
# Pre-trained SR model is loaded.

# %%
for day in list_of_days:
    filename = 'oco2_GEOS_L3CO2_day_'+day+'_B10206Ar.nc4'
    print("===> Processing: %s " % (filename))
    file = NetCDFFile('/data/andria/OCO-2/'+filename)
    to_save = filename.replace('oco2_GEOS_L3CO2_day_', '').replace('_B10206Ar.nc4', '')
    xco2 = np.asarray(file.variables['XCO2'][:])
    xco2 = np.squeeze(xco2)
    lat = np.asarray(file.variables['lat'][:])
    lon = np.asarray(file.variables['lon'][:])

    xco2_norm = normalize_array(xco2)

    arrays_centered_on_factory(coordinates, to_save, lat, lon, 10, xco2_norm)

    print('===> Loading datasets')
    test_set = get_eval_set(os.path.join('/data/andria/Input','emitters'), 16)
    testing_data_loader = DataLoader(dataset=test_set, num_workers=1, batch_size=1, shuffle=False)

    def eval():
        model_16.eval()
        for batch in testing_data_loader:
            with torch.no_grad():
                input, name = Variable(batch[0]), batch[1]
            if cuda:
                input = input.cuda(gpus_list[0])

            t0 = time.time()
            with torch.no_grad():
                prediction_16 = model_16(input)
            t1 = time.time()
            name_16 = name[0].replace('.npy', '_16.npy')
            print("===> Processing: %s || Path: 1-16 || Timer: %.4f sec." % (name_16, (t1 - t0)))

            save_img(prediction_16.cpu().data, name_16)

    eval()
    files = glob.glob('/data/andria/Input/emitters/*')
    for f in files:
        os.remove(f)
# Out:
# ===> Processing: oco2_GEOS_L3CO2_day_20150120_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20150120_0_16.npy || Path: 1-16 || Timer: 1.5118 sec.
# ===> Processing: centered_20150120_5_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150120_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150120_11_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150120_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150120_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150120_6_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150120_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150120_4_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150120_2_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150120_12_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150120_15_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150120_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150120_13_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150120_14_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150120_9_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20150420_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20150420_0_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20150420_11_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150420_13_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20150420_2_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_9_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150420_14_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_7_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_10_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_3_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_15_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150420_12_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150420_5_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150420_8_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150420_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150420_1_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150420_6_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20150720_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20150720_10_16.npy || Path: 1-16 || Timer: 0.0070 sec.
# ===> Processing: centered_20150720_2_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_4_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150720_13_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150720_5_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_9_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_14_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150720_0_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_11_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_15_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_6_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20150720_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20150720_7_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20150720_12_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20151020_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20151020_4_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20151020_0_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20151020_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_9_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_11_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_12_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20151020_5_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20151020_14_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: centered_20151020_15_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20160120_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20160120_6_16.npy || Path: 1-16 || Timer: 0.0070 sec.
# ===> Processing: centered_20160120_5_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160120_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_11_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160120_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_15_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_0_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160120_9_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160120_3_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160120_12_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20160420_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20160420_14_16.npy || Path: 1-16 || Timer: 0.0076 sec.
# ===> Processing: centered_20160420_15_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160420_0_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160420_5_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160420_6_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160420_12_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160420_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160420_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160420_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160420_2_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160420_8_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160420_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160420_9_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160420_4_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160420_11_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: centered_20160420_1_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20160720_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20160720_13_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20160720_1_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160720_5_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20160720_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_9_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20160720_0_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160720_12_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160720_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_15_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_3_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160720_11_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20160720_14_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20160720_7_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20160720_10_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20161020_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20161020_13_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20161020_15_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20161020_12_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_9_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_11_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20161020_10_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20161020_5_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_8_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20161020_0_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20161020_7_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20161020_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_1_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20161020_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20161020_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20170120_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20170120_11_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20170120_13_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170120_15_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20170120_9_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170120_4_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170120_5_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20170120_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_12_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_0_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170120_2_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20170420_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20170420_13_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20170420_15_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170420_0_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170420_11_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_8_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20170420_3_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20170420_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_9_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_5_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170420_7_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20170420_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170420_12_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20170720_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20170720_15_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20170720_12_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20170720_8_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_3_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20170720_5_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20170720_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_11_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_2_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20170720_9_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20170720_0_16.npy || Path: 1-16 || Timer: 0.0054 sec.
# ===> Processing: centered_20170720_6_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20171020_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20171020_4_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20171020_15_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20171020_10_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20171020_12_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20171020_14_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20171020_1_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20171020_5_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20171020_0_16.npy || Path: 1-16 || Timer: 0.0063 sec.
# ===> Processing: centered_20171020_2_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: centered_20171020_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20171020_8_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20171020_9_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20171020_3_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20171020_7_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20171020_11_16.npy || Path: 1-16 || Timer: 0.0059 sec.
# ===> Processing: centered_20171020_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20180120_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20180120_8_16.npy || Path: 1-16 || Timer: 0.0068 sec.
# ===> Processing: centered_20180120_2_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20180120_4_16.npy || Path: 1-16 || Timer: 0.0067 sec.
# ===> Processing: centered_20180120_15_16.npy || Path: 1-16 || Timer: 0.0059 sec.
# ===> Processing: centered_20180120_9_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20180120_1_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20180120_6_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20180120_7_16.npy || Path: 1-16 || Timer: 0.0071 sec.
# ===> Processing: centered_20180120_5_16.npy || Path: 1-16 || Timer: 0.0058 sec.
# ===> Processing: centered_20180120_12_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20180120_0_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20180120_14_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20180120_10_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20180120_3_16.npy || Path: 1-16 || Timer: 0.0057 sec.
# ===> Processing: centered_20180120_13_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20180120_11_16.npy || Path: 1-16 || Timer: 0.0055 sec.
# ===> Processing: oco2_GEOS_L3CO2_day_20180420_B10206Ar.nc4
# ===> Loading datasets
# ===> Processing: centered_20180420_15_16.npy || Path: 1-16 || Timer: 0.0069 sec.
# ===> Processing: centered_20180420_4_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20180420_1_16.npy || Path: 1-16 || Timer: 0.0056 sec.
# ===> Processing: centered_20